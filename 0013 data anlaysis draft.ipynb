# %%
import os
import numpy as np
import pandas as pd

# %%
# Set download URL
host = 'https://orca.casa.ucl.ac.uk'
path = '~jreades/data/London-2016-02-02-listings.csv.gz'   
url  = f'{host}/{path}'

# your code here
df2016 = pd.read_csv(url, compression='gzip', low_memory=False)
print(f"Data frame is {df_2016.shape[0]:,} x {df_2016.shape[1]}")
# Out:
# Data frame is 33,715 x 92

# %%
df2016.describe(percentiles=[.05,0.95]) # 0.5 is always shown
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.371500e+04  3.371500e+04  3.371500e+04         33710.000000
# mean   6.099960e+06  2.016020e+13  1.877962e+07             9.160249
# std    3.153099e+06  6.761819e+00  1.581764e+07            32.132291
# min    8.795000e+03  2.016020e+13  4.320000e+02             1.000000
# 5%     5.455513e+05  2.016020e+13  9.010770e+05             1.000000
# 50%    6.611900e+06  2.016020e+13  1.455477e+07             1.000000
# 95%    1.040332e+07  2.016020e+13  4.875495e+07            39.000000
# max    1.099548e+07  2.016020e+13  5.704495e+07           727.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed      latitude  \
# count               33710.000000                           0.0  33715.000000
# mean                    9.160249                           NaN     51.508903
# std                    32.132291                           NaN      0.040172
# ...

# %%
df2016.dropna(axis=0,
          how='any',
          thresh=None,
          subset=['id','latitude', 'longitude','price'],
          inplace=False)
# Out:
#              id                            listing_url       scrape_id  \
# 0       5910748   https://www.airbnb.com/rooms/5910748  20160202001630
# 1       8950456   https://www.airbnb.com/rooms/8950456  20160202001630
# 2        375799    https://www.airbnb.com/rooms/375799  20160202001630
# 3      10258595  https://www.airbnb.com/rooms/10258595  20160202001630
# 4       8020994   https://www.airbnb.com/rooms/8020994  20160202001630
# ...         ...                                    ...             ...
# 33710  10804057  https://www.airbnb.com/rooms/10804057  20160202001630
# 33711   4065875   https://www.airbnb.com/rooms/4065875  20160202001630
# 33712   9839139   https://www.airbnb.com/rooms/9839139  20160202001630
# 33713  10901103  https://www.airbnb.com/rooms/10901103  20160202001630
# 33714  10954327  https://www.airbnb.com/rooms/10954327  20160202001630
#
#       last_scraped                                 name  \
# 0       2016-02-02       The Beach House in the Suburbs
# ...

# %%
#delete the '$'

# %%
money = ['price']
for m in money:
    print(f"Converting {m}")
    df2016[m] = df2016[m].str.replace('$','', regex=False).str.replace(',','', regex=False).astype('float')
# Out:
# Converting price

# %%
#Filter out the variables to be used

# %%
df2016=df2016.loc[:, ['id','latitude', 'longitude','price']]

# %%
df2016['price']
# Out:
# 0         45.0
# 1         60.0
# 2         80.0
# 3         27.0
# 4         49.0
#          ...
# 33710     70.0
# 33711    159.0
# 33712     70.0
# 33713    205.0
# 33714     50.0
# Name: price, Length: 33715, dtype: float64

# %%
df2016.describe()
# Out:
#                  id      latitude     longitude         price
# count  3.371500e+04  33715.000000  33715.000000  33715.000000
# mean   6.099960e+06     51.508903     -0.126581     96.080083
# std    3.153099e+06      0.040172      0.081387     97.876147
# min    8.795000e+03     51.315444     -0.487079      7.000000
# 25%    3.654366e+06     51.486629     -0.185033     45.000000
# 50%    6.611900e+06     51.513875     -0.120776     75.000000
# 75%    8.851045e+06     51.533437     -0.070986    120.000000
# max    1.099548e+07     51.675061      0.243388   7001.000000

# %%
print(f"The mean price is ${df2016.price.mean():0.2f}")
print(f"The median price is ${df2016.price.median():0.2f}")
# Out:
# The mean price is $96.08
# The median price is $75.00

# %%
import geopandas as gpd
import pandas as pd


# 读取borough shp文件
borough = gpd.read_file("data/statistical-gis-boundaries-london/ESRI/London_Borough_Excluding_MHW.shp")

borough= borough.to_crs(epsg=27700)
# 读取爱彼迎房价数据
data = df2016

# 将经纬度转换为点数据
point = gpd.GeoDataFrame(df2016, geometry=gpd.points_from_xy(df2016.longitude, df2016.latitude, crs=4326))

point= point.to_crs(epsg=27700)

# 将房价数据与行政区块数据连接起来

data2016_borough = gpd.sjoin(point, borough, how="inner",predicate='within')  
data2016_borough_grouped = data_borough.groupby("GSS_CODE").mean()

# %%
data2016_borough_grouped
# Out:
#                      id   latitude  longitude       price  index_right  \
# GSS_CODE
# E09000001  6.267780e+06  51.516199  -0.091771  146.121212         32.0
# E09000002  5.711088e+06  51.539925   0.112647   47.473684         31.0
# E09000003  6.672238e+06  51.597287  -0.200986   60.800000          9.0
# E09000004  5.762726e+06  51.464988   0.132321   44.127273         14.0
# E09000005  5.872888e+06  51.545185  -0.234122   65.680342          8.0
# E09000006  6.301246e+06  51.404687  -0.007440   58.175439          2.0
# E09000007  5.927139e+06  51.534803  -0.143085  116.059349         25.0
# E09000008  5.746996e+06  51.384476  -0.092924   54.791262          1.0
# E09000009  6.088779e+06  51.512248  -0.295652   66.387033          4.0
# E09000010  6.182737e+06  51.637176  -0.090033   55.112069         15.0
# E09000011  5.719313e+06  51.481430   0.030262   72.924444         13.0
# E09000012  5.854812e+06  51.545513  -0.069260   81.775000         28.0
# ...

# %%
data2016_borough_grouped
# Out:
#                      id   latitude  longitude       price  index_right  \
# GSS_CODE
# E09000001  6.267780e+06  51.516199  -0.091771  146.121212         32.0
# E09000002  5.711088e+06  51.539925   0.112647   47.473684         31.0
# E09000003  6.672238e+06  51.597287  -0.200986   60.800000          9.0
# E09000004  5.762726e+06  51.464988   0.132321   44.127273         14.0
# E09000005  5.872888e+06  51.545185  -0.234122   65.680342          8.0
# E09000006  6.301246e+06  51.404687  -0.007440   58.175439          2.0
# E09000007  5.927139e+06  51.534803  -0.143085  116.059349         25.0
# E09000008  5.746996e+06  51.384476  -0.092924   54.791262          1.0
# E09000009  6.088779e+06  51.512248  -0.295652   66.387033          4.0
# E09000010  6.182737e+06  51.637176  -0.090033   55.112069         15.0
# E09000011  5.719313e+06  51.481430   0.030262   72.924444         13.0
# E09000012  5.854812e+06  51.545513  -0.069260   81.775000         28.0
# ...

# %%
data2016_borough_grouped.price.to_csv("airbnb_mean_prices2016.csv")

# %%
data2016_borough_grouped_df = pd.DataFrame(data2016_borough_grouped)

# %%
airbnb2016=data2016_borough_grouped_df.price

# %%
airbnb2016
# Out:
# GSS_CODE
# E09000001    146.121212
# E09000002     47.473684
# E09000003     60.800000
# E09000004     44.127273
# E09000005     65.680342
# E09000006     58.175439
# E09000007    116.059349
# E09000008     54.791262
# E09000009     66.387033
# E09000010     55.112069
# E09000011     72.924444
# E09000012     81.775000
# E09000013    104.989785
# E09000014     56.714004
# E09000015     46.921053
# E09000016     56.866667
# E09000017     53.930233
# E09000018     88.376168
# E09000019     93.952546
# E09000020    147.016009
# E09000021     69.967914
# E09000022     81.106661
# E09000023     62.523148
# E09000024     85.291045
# E09000025     67.555725
# E09000026     59.688742
# E09000027    103.872690
# E09000028     85.509425
# E09000029     54.018868
# E09000030     76.823138
# E09000031     60.923077
# E09000032     92.071386
# E09000033    138.513940
# Name: price, dtype: float64

# %%
data2016_borough_grouped.price
# Out:
# GSS_CODE
# E09000001    146.121212
# E09000002     47.473684
# E09000003     60.800000
# E09000004     44.127273
# E09000005     65.680342
# E09000006     58.175439
# E09000007    116.059349
# E09000008     54.791262
# E09000009     66.387033
# E09000010     55.112069
# E09000011     72.924444
# E09000012     81.775000
# E09000013    104.989785
# E09000014     56.714004
# E09000015     46.921053
# E09000016     56.866667
# E09000017     53.930233
# E09000018     88.376168
# E09000019     93.952546
# E09000020    147.016009
# E09000021     69.967914
# E09000022     81.106661
# E09000023     62.523148
# E09000024     85.291045
# E09000025     67.555725
# E09000026     59.688742
# E09000027    103.872690
# E09000028     85.509425
# E09000029     54.018868
# E09000030     76.823138
# E09000031     60.923077
# E09000032     92.071386
# E09000033    138.513940
# Name: price, dtype: float64

# %%
# Set download URL
host = 'https://orca.casa.ucl.ac.uk'
path = '~jreades/data/London-2021-10-listings.csv.gz'  
url  = f'{host}/{path}'

# your code here
df = pd.read_csv(url, compression='gzip', low_memory=False)
print(f"Data frame is {df.shape[0]:,} x {df.shape[1]}")
# Out:
# Data frame is 70,617 x 74

# %%
df.describe(percentiles=[.05,0.95]) # 0.5 is always shown
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  7.061700e+04  7.061700e+04  7.061700e+04         69942.000000
# mean   2.773223e+07  2.021091e+13  1.051931e+08            29.206371
# std    1.485129e+07  1.048445e+01  1.121846e+08           142.976689
# min    1.391300e+04  2.021091e+13  2.010000e+03             0.000000
# 5%     3.726669e+06  2.021091e+13  2.125620e+06             0.000000
# 50%    2.738781e+07  2.021091e+13  5.302758e+07             1.000000
# 95%    5.069131e+07  2.021091e+13  3.530251e+08            92.000000
# max    5.216677e+07  2.021091e+13  4.221723e+08          3508.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed      latitude  \
# count               69942.000000                           0.0  70617.000000
# mean                   29.206371                           NaN     51.509848
# std                   142.976689                           NaN      0.047755
# ...

# %%
df.dropna(axis=0,
          how='any',
          thresh=None,
          subset=['id','latitude', 'longitude','price'],
          inplace=False)
# Out:
#              id                            listing_url       scrape_id  \
# 0         13913     https://www.airbnb.com/rooms/13913  20210909211636
# 1         15400     https://www.airbnb.com/rooms/15400  20210909211636
# 2         17402     https://www.airbnb.com/rooms/17402  20210909211636
# 3         17506     https://www.airbnb.com/rooms/17506  20210909211636
# 4         24328     https://www.airbnb.com/rooms/24328  20210909211636
# ...         ...                                    ...             ...
# 70612  52161425  https://www.airbnb.com/rooms/52161425  20210909211636
# 70613  52162679  https://www.airbnb.com/rooms/52162679  20210909211636
# 70614  52163425  https://www.airbnb.com/rooms/52163425  20210909211636
# 70615  52163904  https://www.airbnb.com/rooms/52163904  20210909211636
# 70616  52166774  https://www.airbnb.com/rooms/52166774  20210909211636
#
#       last_scraped                                               name  \
# ...

# %%
money = ['price']
for m in money:
    print(f"Converting {m}")
    df[m] = df[m].str.replace('$','', regex=False).str.replace(',','', regex=False).astype('float')
# Out:
# Converting price

# %%
df2021=df.loc[:, ['id','latitude', 'longitude','price']]

# %%
df2021
# Out:
#              id   latitude  longitude  price
# 0         13913  51.568020  -0.111210   65.0
# 1         15400  51.487800  -0.168130   75.0
# 2         17402  51.521950  -0.140940  307.0
# 3         17506  51.479350  -0.197430  150.0
# 4         24328  51.472980  -0.163760  195.0
# ...         ...        ...        ...    ...
# 70612  52161425  51.546600  -0.205550   32.0
# 70613  52162679  51.530435  -0.054673  336.0
# 70614  52163425  51.543330   0.156380  120.0
# 70615  52163904  51.510796  -0.181146  206.0
# 70616  52166774  51.520716  -0.158749   80.0
#
# [70617 rows x 4 columns]

# %%
df2021.describe()
# Out:
#                  id      latitude     longitude         price
# count  7.061700e+04  70617.000000  70617.000000  70617.000000
# mean   2.773223e+07     51.509848     -0.128761    137.489528
# std    1.485129e+07      0.047755      0.096498    302.702928
# min    1.391300e+04     51.297330     -0.508870      0.000000
# 25%    1.581610e+07     51.484120     -0.188630     45.000000
# 50%    2.738781e+07     51.513910     -0.126280     80.000000
# 75%    4.052325e+07     51.539700     -0.069460    139.000000
# max    5.216677e+07     51.686410      0.288570  17709.000000

# %%
print(f"The mean price is ${df.price.mean():0.2f}")
print(f"The median price is ${df.price.median():0.2f}")
# Out:
# The mean price is $137.49
# The median price is $80.00

# %%
import geopandas as gpd
import pandas as pd


# 读取borough shp文件
borough = gpd.read_file("data/statistical-gis-boundaries-london/ESRI/London_Borough_Excluding_MHW.shp")

borough= borough.to_crs(epsg=27700)
# 读取爱彼迎房价数据
data = df2021

# 将经纬度转换为点数据
point = gpd.GeoDataFrame(df2021, geometry=gpd.points_from_xy(df2021.longitude, df2021.latitude, crs=4326))

point= point.to_crs(epsg=27700)

# 将房价数据与行政区块数据连接起来

data_borough = gpd.sjoin(point, borough, how="inner",predicate='within')  
data2021_borough_grouped = data_borough.groupby("GSS_CODE").mean()

# %%
data2021_borough_grouped
# Out:
#                      id   latitude  longitude       price  index_right  \
# GSS_CODE
# E09000001  3.196386e+07  51.514657  -0.090680  233.869318         32.0
# E09000002  3.334314e+07  51.543929   0.119642   72.875312         31.0
# E09000003  2.920885e+07  51.597112  -0.207674  130.208519          9.0
# E09000004  3.359817e+07  51.471995   0.138712   66.356890         14.0
# E09000005  2.719853e+07  51.547121  -0.237826  125.802852          8.0
# E09000006  2.809019e+07  51.400442   0.002100   78.947748          2.0
# E09000007  2.911931e+07  51.537515  -0.148323  148.002035         25.0
# E09000008  3.118254e+07  51.382928  -0.096320   66.705660          1.0
# E09000009  2.768028e+07  51.513824  -0.299246   91.444651          4.0
# E09000010  2.894413e+07  51.634474  -0.086686   69.187394         15.0
# E09000011  2.968208e+07  51.482459   0.040718  135.380572         13.0
# E09000012  2.361275e+07  51.546285  -0.068413  100.353562         28.0
# ...

# %%
data2021_borough_grouped.price
# Out:
# GSS_CODE
# E09000001    233.869318
# E09000002     72.875312
# E09000003    130.208519
# E09000004     66.356890
# E09000005    125.802852
# E09000006     78.947748
# E09000007    148.002035
# E09000008     66.705660
# E09000009     91.444651
# E09000010     69.187394
# E09000011    135.380572
# E09000012    100.353562
# E09000013    138.551072
# E09000014     97.877949
# E09000015     74.633641
# E09000016     84.845560
# E09000017    104.585827
# E09000018    112.323819
# E09000019    139.949430
# E09000020    205.254110
# E09000021    114.294455
# E09000022     99.999225
# E09000023     88.173583
# E09000024    119.678540
# E09000025     89.907990
# E09000026     75.127466
# E09000027    137.419103
# E09000028    173.169880
# E09000029     75.982993
# E09000030    103.374649
# E09000031     75.057453
# E09000032    131.286308
# E09000033    241.698767
# Name: price, dtype: float64

# %%
data2021_borough_grouped.price.to_csv("airbnb_mean_prices2021.csv")

# %%
import pandas as pd
airbnb2016= pd.read_csv("airbnb_mean_prices2016.csv")
airbnb2021= pd.read_csv("airbnb_mean_prices2021.csv")

# %%
price =airbnb2016.loc[:,'price']

# %%
#Airbnb Rental Growth 2016 to 2021
airbnb2021_2016=[airbnb2021.price-airbnb2016.price]

# %%
airbnb2021_2016
# Out:
# [0      87.748106
#  1      25.401628
#  2      69.408519
#  3      22.229618
#  4      60.122510
#  5      20.772309
#  6      31.942686
#  7      11.914398
#  8      25.057617
#  9      14.075325
#  10     62.456128
#  11     18.578562
#  12     33.561287
#  13     41.163945
#  14     27.712588
#  15     27.978893
#  16     50.655594
#  17     23.947651
#  18     45.996884
#  19     58.238100
#  20     44.326541
#  21     18.892565
#  22     25.650435
#  23     34.387495
#  24     22.352265
#  25     15.438724
#  26     33.546413
#  27     87.660455
#  28     21.964125
#  29     26.551511
#  30     14.134376
#  31     39.214922
#  32    103.184827
#  Name: price, dtype: float64]

# %%
#Distance from CDB

# %%
distance= pd.read_csv("CBD.csv")

# %%
distance_borough= distance.loc[:,'distance']

# %%
#london house price

# %%
house_price=pd.read_csv("LondonHousePrice.csv")

# %%
house_price2016=house_price.loc[:,'2016']

# %%
house_price2021=house_price.loc[:,'2021']

# %%
house_price2021_2016=house_price2021-house_price2016

# %%
house_price2021_2016
# Out:
# 0     -5851
# 1     42588
# 2     24789
# 3     44446
# 4     24268
# 5     37964
# 6     28950
# 7     39300
# 8     29825
# 9     38525
# 10    32554
# 11    56122
# 12     9622
# 13    47327
# 14    32065
# 15    49029
# 16    30473
# 17    38175
# 18    48165
# 19    45581
# 20    29813
# 21    18922
# 22    35464
# 23    49393
# 24    39794
# 25    62246
# 26    57536
# 27     4434
# 28    36873
# 29    -2311
# 30    64459
# 31     2772
# 32   -32766
# 33    31193
# dtype: int64

# %%
house_price2021_2016.to_csv("house_price2021_2016.csv")

# %%
#coombine the 'house_price2021_2016' 'airbnb2021_2016'  'distance_borough' dataset we get new dataframe'housedata'

# %%
housedata=pd.read_csv("housedata.csv")

# %%
housedata
# Out:
#     Unnamed: 0                    NAME   GSS_CODE  house_price2021_2016  \
# 0            1          City of London  E09000001                 -5851
# 1            2    Barking and Dagenham  E09000002                 42588
# 2            3                  Barnet  E09000003                 24789
# 3            4                  Bexley  E09000004                 44446
# 4            5                   Brent  E09000005                 24268
# 5            6                 Bromley  E09000006                 37964
# 6            7                  Camden  E09000007                 28950
# 7            8                 Croydon  E09000008                 39300
# 8            9                  Ealing  E09000009                 29825
# 9           10                 Enfield  E09000010                 38525
# 10          11               Greenwich  E09000011                 32554
# 11          12                 Hackney  E09000012                 56122
# ...

# %%
#linear regression

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

import numpy as np

import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sn

# %%
model = sm.formula.ols('house_price2021_2016 ~ airbnb2021_2016 + distance_borough',housedata).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     house_price2021_2016   R-squared:                       0.443
# Model:                              OLS   Adj. R-squared:                  0.406
# Method:                   Least Squares   F-statistic:                     11.95
# Date:                  Fri, 13 Jan 2023   Prob (F-statistic):           0.000152
# Time:                          22:40:55   Log-Likelihood:                -365.21
# No. Observations:                    33   AIC:                             736.4
# Df Residuals:                        30   BIC:                             740.9
# Df Model:                             2
# Covariance Type:              nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...
